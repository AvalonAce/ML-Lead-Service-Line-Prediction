# %% [markdown]
# # NJ Preprocessing
# ---

# %%
# Imports
import pandas as pd
import numpy as np
import re
from datetime import datetime

# %%
# Load Data
data1 = pd.read_csv('../data/raw/NJ1.csv', encoding='latin-1')
data2 = pd.read_csv('../data/raw/NJ2.csv', encoding='latin-1')
data3 = pd.read_csv('../data/raw/NJ3.csv', encoding='latin-1')
data = pd.concat([data1, data2, data3s], ignore_index=True)
data.head()
